# %%
from google import genai

client = genai.Client()
# 文字输出
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="用中文解释AI大模型是如何工作的",
)

print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 简单来说，AI大模型（如ChatGPT、Claude等）的工作原理可以被看作是一个**超级强大的“文字接龙”游戏**，但其背后依靠的是极其复杂的数学和海量的数据。
#
# 我们可以从以下四个核心层面来理解它的工作机制：
#
# ### 1. 核心任务：预测下一个字
# AI大模型本质上是一个**概率预测机器**。
# 当你输入一个问题时，它并不是在“思考”，而是在计算：**“根据之前的这些词，下一个最有可能出现的词（或字）是什么？”**
#
# *   **例子**：如果你输入“床前明月”，AI会根据它读过的海量诗歌，计算出下一个字是“光”的概率最高（比如99%）。
# *   **连点成线**：它预测出第一个字后，会把这个字放进已有的句子中，再预测下一个字。就这样一个字一个字地蹦，最后连成一段话。
#
# ### 2. 学习过程：疯狂的阅读（预训练）
# AI之所以知道下一个字该说什么，是因为它经历了**“预训练”（Pre-training）**阶段。
#
# *   **海量数据**：科学家把互联网上的书籍、文章、代码、对话等几乎人类所有的公开文本都“喂”给了它。
# *   **寻找模式**：在阅读过程中，AI并不理解文字背后的真正含义，但它记住了词与词之间的**数学关系**。它发现“苹果”经常和“吃”、“红的”、“手机”出现在一起，而很少和“开飞机”出现在一起。
# *   **参数化**：AI内部有数千亿个“旋钮”（称为参数）。在学习时，它不断调整这些旋钮，直到它能准确预测出大部分人类文本的走向。
#
# ### 3. 核心架构：注意力机制（Transformer）
# 现在的AI大模型大多基于一种叫 **Transformer** 的架构。它最厉害的地方在于**“注意力机制”（Attention）**。
#
# *   **理解语境**：在老一代AI中，如果句子很长，它读到后面就忘了前面。但注意力机制能让AI在处理每一个词时，都去扫描整个句子中相关的词。
# *   **例子**：在句子“河边的**银行**（Bank）”和“存钱的**银行**（Bank）”中，AI能通过“河边”或“存钱”这两个关键词，自动给“银行”赋予不同的数学定义。
#
# ### 4. 调教阶段：让它像个人（微调与对齐）
# 仅仅会文字接龙是不够的，因为它可能会学到互联网上的脏话或废话。为了让它变好用，还需要两个步骤：
#
# 1.  **有监督微调（SFT）**：人类老师写下大量标准的问题和答案，手把手教AI：“当用户问你问题时，你应该这样回答。”
# 2.  **强化学习（RLHF）**：让AI生成几个不同的答案，由人类来打分（哪个更有礼貌、更准确）。AI会根据这些反馈调整自己，变得越来越符合人类的价值观和交流习惯。
#
# ### 5. 总结：它到底是什么？
# *   **它不是什么**：它不是一个有意识的灵魂，也不是一个联网搜索的计算器（虽然它可以调用搜索工具）。
# *   **它是什么**：它是**人类知识的数学压缩包**。它通过极其复杂的统计学规律，模仿了人类处理语言的能力。
#
# **打个比方：**
# AI大模型就像一个读过世界上所有书籍的**超级图书馆管理员**。虽然它不一定真的“理解”什么是生活，但当你开口说出前半句，他能立刻凭借惊人的记忆和联想能力，为你补全剩下的部分，而且听起来逻辑严密、充满智慧。

# %%
from PIL import Image
# 图像理解
image = Image.open("dog_and_girl.jpeg")

# 注意：contents 变成了一个列表，里面同时放了图片对象和文字
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[image, "帮我解释下这张照片"]
)

print(response.text)
# Out:
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 这张照片呈现了一个非常温馨、治愈且充满情感的瞬间。我们可以从以下几个维度来解读：
#
# **1. 核心主题：深厚的情感纽带**
# 照片的中心是一只浅色的拉布拉多犬和一位年轻女性。他们正在进行“击掌”或“握手”的互动。这个动作象征着人类与宠物之间的沟通、信任和默契。狗狗专注的神情和女性脸上灿烂的笑容，传达出一种纯粹的快乐和相互的陪伴。
#
# **2. 环境与氛围：黄金时刻的宁静**
# *   **光影：** 照片拍摄于“黄金时刻”（日出或日落时分）。柔和、温暖的橘黄色阳光从侧后方照射过来，给主体勾勒出一层金色的轮廓，使整个画面显得神圣而柔和。
# *   **背景：** 背景是广阔的沙滩和波浪轻轻拍打的海面。这种自然的背景增加了画面的空间感，也营造出一种远离尘嚣、宁静祥和的氛围。
#
# **3. 细节捕捉：**
# *   **狗狗：** 它戴着彩色的胸背带，坐姿端正，显得既乖巧又专业。它抬起的爪子和专注的眼神显示出它对主人的高度配合。
# *   **女性：** 她穿着休闲的格子衬衫，光着脚坐在沙滩上，这种随意的装束体现了她与大自然的亲近，以及在宠物面前最放松的状态。
# *   **构图：** 拍摄者采用了较低的角度，与主体视线齐平，这增加了观众的代入感，仿佛我们也正坐在沙滩上见证这一幕。
#
# **4. 情感表达：**
# 这张照片不仅仅是人与动物的合影，它更像是一个关于“陪伴”的故事。它捕捉到了生命中那些简单却极其珍贵的瞬间——不需要复杂的言语，一个眼神、一个动作，就能感受到彼此之间的爱与温暖。
#
# **总结：**
# 这是一张艺术感与情感并存的摄影作品。它利用完美的光线和自然背景，成功地定格了人与狗之间那份跨越物种的、纯粹而动人的友谊。让人看后会不由自主地感到心情平静和愉悦。

# %%
# 视频理解
import time

# 1. 上传视频文件
print("正在上传视频...")
video_file = client.files.upload(file="car.mp4") # 汽车剐蹭视频
print(f"上传成功: {video_file.name}")

# 2. 等待视频处理 (关键步骤！)
# 视频上传后，Google 需要几秒钟在云端进行转码。
while video_file.state.name == "PROCESSING":
    print("视频处理中，请稍候...")
    time.sleep(2)
    video_file = client.files.get(name=video_file.name)

if video_file.state.name == "FAILED":
    raise ValueError("视频处理失败")

print("视频就绪，开始推理...")

# 3. 多模态推理
# 将上传好的 video_file 对象直接放入 contents 列表
response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents=[
        video_file, 
        "详细描述视频里发生了什么？如果有对话，请把关键对话提取出来。"
    ]
)

print(response.text)

# 4. (可选) 删除云端文件以节省空间
# client.files.delete(name=video_file.name)
# Out:
# 正在上传视频...
# 上传成功: files/gy2h449pv8su
# 视频处理中，请稍候...
# 视频处理中，请稍候...
# 视频就绪，开始推理...
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# 视频详细描述了以下内容：
#
# **场景描述：**
#
# 1. **车辆受损情况 (00:00 - 00:07)：** 视频开头展示了一辆银灰色 SUV 的右后侧车门及轮眉处有明显的刮蹭痕迹，白色的底漆露出，且车门有明显的凹陷变形。女性旁白表示维修费用估计得 2000 多元，并提到是在拐弯时撞到了墙。
# 2. **事故原因及受损细节 (00:08 - 00:20)：** 一名男子（丐丐）站在车旁，指着受损部位解释说，是在下地下车库时撞到了墙。他详细展示了从轮眉到门把手位置的大面积凹陷和掉漆情况，表示这肯定需要做钣金修复。
# 3. **关于保险的讨论 (00:21 - 00:26)：** 镜头转向两人，女子询问丈夫是走保险还是自费维修。男子无奈地表示，因为没有购买车损险，所以只能自己掏钱修理。
# 4. **事故现场展示 (00:27 - 00:31)：** 视频最后切换到了地下车库的事故现场。画面显示车库的一个墙角处有明显的刮蹭痕迹，水泥脱落。男子指着墙角说，这就是刚才撞到的地方。
#
# **关键对话提取：**
#
# * **女：** “完了，这没个2000块钱修不出来。丐丐刚才不小心拐弯的时候直接撞墙上了，车门都给撞变形了。”
# * **男（丐丐）：** “下地下车库的时候，门撞墙上了，整个这个门都凹回去了，这肯定得钣金。下面的漆都掉了，你看看。从这块到这块，到门把手这块，这块整个门都凹回去了。”
# * **女：** “老公你说咱们这，走保险呀还是自己修呀？”
# * **男：** “咱们没有车损险，咱只能自己修了。”
# * **女（旁白）：** “这就是刚才拐弯的时候，丐丐磕的地方。”
# * **男：** “这个地方，这不就是我刚才磕的这个地方。”
